# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, ConcatDataset, Dataset
import os
import numpy as np
from sklearn.model_selection import train_test_split

os.chdir("/root/dev/vcmr")

# %%
# HPARAMS
num_epochs = 1000
learning_rate = 1e-4
batch_size = 64

# %%
# PRELOAD
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
image_dir = './image_features_train'
music_dir = './music_features_train'

files = sorted([f for f in os.listdir(image_dir) if f.endswith('.npy')])
filenames = [os.path.splitext(f)[0] for f in files]
image_embeddings = []
music_embeddings = []
for f in files:
    image_embed = np.load(os.path.join(image_dir, f)).astype(np.float32)
    music_embed = np.load(os.path.join(music_dir, f)).astype(np.float32)
    image_embeddings.append(image_embed)
    music_embeddings.append(music_embed)
image_embeddings = torch.tensor(image_embeddings, dtype=torch.float32)
music_embeddings = torch.tensor(music_embeddings, dtype=torch.float32)

num_samples = len(filenames)
num_image_embeddings = image_embeddings.size(1)
num_music_embeddings = music_embeddings.size(1)
print(num_samples, num_image_embeddings, num_music_embeddings)

train_indices, val_indices = train_test_split(list(range(num_samples)), test_size=0.2, random_state=42)
# Out:
# /tmp/ipykernel_3552084/163114639.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   image_embeddings = torch.tensor(image_embeddings, dtype=torch.float32)
# 37656 512 512

# %%
class PairDataset(Dataset):
    def __init__(self, image_embeds, music_embeds, indices, positive=True):
        self.image_embeds = image_embeds
        self.music_embeds = music_embeds
        self.indices = indices
        self.positive = positive
        self.labels = torch.ones(len(indices), dtype=torch.float32) if positive else torch.ones(len(indices), dtype=torch.float32) * -1.0

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        i = self.indices[idx]
        img = self.image_embeds[i]
        if self.positive:
            music = self.music_embeds[i]
            label = self.labels[idx]
        else:
            j = (i + 4) % self.image_embeds.size(0)
            music = self.music_embeds[j]
            label = self.labels[idx]
        return img, music, label

train_positive_dataset = PairDataset(image_embeddings, music_embeddings, train_indices, positive=True)
train_negative_dataset = PairDataset(image_embeddings, music_embeddings, train_indices, positive=False)
val_positive_dataset = PairDataset(image_embeddings, music_embeddings, val_indices, positive=True)
val_negative_dataset = PairDataset(image_embeddings, music_embeddings, val_indices, positive=False)
train_dataset = ConcatDataset([train_positive_dataset, train_negative_dataset])
val_dataset = ConcatDataset([val_positive_dataset, val_negative_dataset])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)

# %%
# LOSS
def cosine_similarity_loss(image_embeds, music_embeds, labels):
    loss = F.cosine_embedding_loss(image_embeds, music_embeds, labels)
    return loss

# MODEL
class ProjectionHead(nn.Module):
    def __init__(self, input_dim=512, output_dim=128):
        super(ProjectionHead, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(input_dim, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Linear(2048, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Linear(512, output_dim)
        )
    def forward(self, x):
        return self.mlp(x)

image_proj = ProjectionHead(input_dim=512, output_dim=128).to(device)
music_proj = ProjectionHead(input_dim=512, output_dim=128).to(device)

# OPT
optimizer = torch.optim.Adam(
    list(image_proj.parameters()) + list(music_proj.parameters()), lr=learning_rate
)

from torch.amp import autocast, GradScaler

scaler = GradScaler()
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
for epoch in range(num_epochs):
    image_proj.train()
    music_proj.train()
    train_loss = 0.0
    for image_embed, music_embed, label in train_loader:
        image_embed = image_embed.to(device, non_blocking=True)
        music_embed = music_embed.to(device, non_blocking=True)
        label = label.to(device, non_blocking=True)
        optimizer.zero_grad()

        with autocast("cuda"):
            projected_image = image_proj(image_embed)
            projected_music = music_proj(music_embed)
            loss = cosine_similarity_loss(projected_image, projected_music, label)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)

    image_proj.eval()
    music_proj.eval()
    val_loss = 0.0
    with torch.no_grad():
        for image_embed, music_embed, label in val_loader:
            image_embed = image_embed.to(device, non_blocking=True)
            music_embed = music_embed.to(device, non_blocking=True)
            label = label.to(device, non_blocking=True)

            with autocast("cuda"):
                projected_image = image_proj(image_embed)
                projected_music = music_proj(music_embed)
                loss = cosine_similarity_loss(projected_image, projected_music, label)
            val_loss += loss.item()
    avg_val_loss = val_loss / len(val_loader)

    scheduler.step()

    print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1/1000, Train Loss: 0.3883, Val Loss: 0.3587
# Epoch 2/1000, Train Loss: 0.3395, Val Loss: 0.3536
# Epoch 3/1000, Train Loss: 0.3157, Val Loss: 0.3510
# Epoch 4/1000, Train Loss: 0.2935, Val Loss: 0.3528
# Epoch 5/1000, Train Loss: 0.2733, Val Loss: 0.3505
# Epoch 6/1000, Train Loss: 0.2274, Val Loss: 0.3510
# Epoch 7/1000, Train Loss: 0.2130, Val Loss: 0.3542
# Epoch 8/1000, Train Loss: 0.2051, Val Loss: 0.3554
# Epoch 9/1000, Train Loss: 0.1977, Val Loss: 0.3564
# Epoch 10/1000, Train Loss: 0.1922, Val Loss: 0.3566
# Epoch 11/1000, Train Loss: 0.1826, Val Loss: 0.3579
# Epoch 12/1000, Train Loss: 0.1824, Val Loss: 0.3589
# Epoch 13/1000, Train Loss: 0.1805, Val Loss: 0.3590
# Epoch 14/1000, Train Loss: 0.1799, Val Loss: 0.3590
# Epoch 15/1000, Train Loss: 0.1798, Val Loss: 0.3591
# Epoch 16/1000, Train Loss: 0.1785, Val Loss: 0.3593
# Epoch 17/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 18/1000, Train Loss: 0.1778, Val Loss: 0.3598
# Epoch 19/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 20/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 21/1000, Train Loss: 0.1781, Val Loss: 0.3590
# Epoch 22/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 23/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 24/1000, Train Loss: 0.1778, Val Loss: 0.3597
# Epoch 25/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 26/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 27/1000, Train Loss: 0.1783, Val Loss: 0.3593
# Epoch 28/1000, Train Loss: 0.1778, Val Loss: 0.3594
# Epoch 29/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 30/1000, Train Loss: 0.1782, Val Loss: 0.3591
# Epoch 31/1000, Train Loss: 0.1775, Val Loss: 0.3599
# Epoch 32/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 33/1000, Train Loss: 0.1778, Val Loss: 0.3597
# Epoch 34/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 35/1000, Train Loss: 0.1783, Val Loss: 0.3595
# Epoch 36/1000, Train Loss: 0.1779, Val Loss: 0.3602
# Epoch 37/1000, Train Loss: 0.1777, Val Loss: 0.3598
# Epoch 38/1000, Train Loss: 0.1784, Val Loss: 0.3595
# Epoch 39/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 40/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 41/1000, Train Loss: 0.1776, Val Loss: 0.3600
# Epoch 42/1000, Train Loss: 0.1785, Val Loss: 0.3602
# Epoch 43/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 44/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 45/1000, Train Loss: 0.1782, Val Loss: 0.3602
# Epoch 46/1000, Train Loss: 0.1776, Val Loss: 0.3596
# Epoch 47/1000, Train Loss: 0.1781, Val Loss: 0.3594
# Epoch 48/1000, Train Loss: 0.1778, Val Loss: 0.3598
# Epoch 49/1000, Train Loss: 0.1778, Val Loss: 0.3600
# Epoch 50/1000, Train Loss: 0.1784, Val Loss: 0.3593
# Epoch 51/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 52/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 53/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 54/1000, Train Loss: 0.1776, Val Loss: 0.3592
# Epoch 55/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 56/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 57/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 58/1000, Train Loss: 0.1783, Val Loss: 0.3593
# Epoch 59/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 60/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 61/1000, Train Loss: 0.1778, Val Loss: 0.3599
# Epoch 62/1000, Train Loss: 0.1783, Val Loss: 0.3596
# Epoch 63/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 64/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 65/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 66/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 67/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 68/1000, Train Loss: 0.1780, Val Loss: 0.3598
# Epoch 69/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 70/1000, Train Loss: 0.1781, Val Loss: 0.3601
# Epoch 71/1000, Train Loss: 0.1784, Val Loss: 0.3602
# Epoch 72/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 73/1000, Train Loss: 0.1781, Val Loss: 0.3595
# Epoch 74/1000, Train Loss: 0.1780, Val Loss: 0.3592
# Epoch 75/1000, Train Loss: 0.1776, Val Loss: 0.3596
# Epoch 76/1000, Train Loss: 0.1777, Val Loss: 0.3591
# Epoch 77/1000, Train Loss: 0.1776, Val Loss: 0.3593
# Epoch 78/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 79/1000, Train Loss: 0.1783, Val Loss: 0.3599
# Epoch 80/1000, Train Loss: 0.1777, Val Loss: 0.3597
# Epoch 81/1000, Train Loss: 0.1780, Val Loss: 0.3605
# Epoch 82/1000, Train Loss: 0.1778, Val Loss: 0.3601
# Epoch 83/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 84/1000, Train Loss: 0.1778, Val Loss: 0.3591
# Epoch 85/1000, Train Loss: 0.1782, Val Loss: 0.3593
# Epoch 86/1000, Train Loss: 0.1781, Val Loss: 0.3595
# Epoch 87/1000, Train Loss: 0.1778, Val Loss: 0.3602
# Epoch 88/1000, Train Loss: 0.1785, Val Loss: 0.3596
# Epoch 89/1000, Train Loss: 0.1782, Val Loss: 0.3593
# Epoch 90/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 91/1000, Train Loss: 0.1784, Val Loss: 0.3603
# Epoch 92/1000, Train Loss: 0.1780, Val Loss: 0.3602
# Epoch 93/1000, Train Loss: 0.1783, Val Loss: 0.3596
# Epoch 94/1000, Train Loss: 0.1777, Val Loss: 0.3593
# Epoch 95/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 96/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 97/1000, Train Loss: 0.1775, Val Loss: 0.3596
# Epoch 98/1000, Train Loss: 0.1783, Val Loss: 0.3599
# Epoch 99/1000, Train Loss: 0.1776, Val Loss: 0.3598
# Epoch 100/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 101/1000, Train Loss: 0.1775, Val Loss: 0.3596
# Epoch 102/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 103/1000, Train Loss: 0.1777, Val Loss: 0.3596
# Epoch 104/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 105/1000, Train Loss: 0.1781, Val Loss: 0.3590
# Epoch 106/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 107/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 108/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 109/1000, Train Loss: 0.1784, Val Loss: 0.3588
# Epoch 110/1000, Train Loss: 0.1784, Val Loss: 0.3595
# Epoch 111/1000, Train Loss: 0.1782, Val Loss: 0.3593
# Epoch 112/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 113/1000, Train Loss: 0.1780, Val Loss: 0.3592
# Epoch 114/1000, Train Loss: 0.1778, Val Loss: 0.3597
# Epoch 115/1000, Train Loss: 0.1778, Val Loss: 0.3593
# Epoch 116/1000, Train Loss: 0.1778, Val Loss: 0.3594
# Epoch 117/1000, Train Loss: 0.1780, Val Loss: 0.3600
# Epoch 118/1000, Train Loss: 0.1778, Val Loss: 0.3600
# Epoch 119/1000, Train Loss: 0.1777, Val Loss: 0.3599
# Epoch 120/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 121/1000, Train Loss: 0.1780, Val Loss: 0.3601
# Epoch 122/1000, Train Loss: 0.1779, Val Loss: 0.3603
# Epoch 123/1000, Train Loss: 0.1781, Val Loss: 0.3595
# Epoch 124/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 125/1000, Train Loss: 0.1782, Val Loss: 0.3600
# Epoch 126/1000, Train Loss: 0.1784, Val Loss: 0.3601
# Epoch 127/1000, Train Loss: 0.1783, Val Loss: 0.3600
# Epoch 128/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 129/1000, Train Loss: 0.1784, Val Loss: 0.3598
# Epoch 130/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 131/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 132/1000, Train Loss: 0.1779, Val Loss: 0.3600
# Epoch 133/1000, Train Loss: 0.1777, Val Loss: 0.3601
# Epoch 134/1000, Train Loss: 0.1776, Val Loss: 0.3594
# Epoch 135/1000, Train Loss: 0.1776, Val Loss: 0.3593
# Epoch 136/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 137/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 138/1000, Train Loss: 0.1783, Val Loss: 0.3595
# Epoch 139/1000, Train Loss: 0.1778, Val Loss: 0.3600
# Epoch 140/1000, Train Loss: 0.1780, Val Loss: 0.3601
# Epoch 141/1000, Train Loss: 0.1777, Val Loss: 0.3601
# Epoch 142/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 143/1000, Train Loss: 0.1779, Val Loss: 0.3593
# Epoch 144/1000, Train Loss: 0.1776, Val Loss: 0.3600
# Epoch 145/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 146/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 147/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 148/1000, Train Loss: 0.1776, Val Loss: 0.3598
# Epoch 149/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 150/1000, Train Loss: 0.1778, Val Loss: 0.3593
# Epoch 151/1000, Train Loss: 0.1780, Val Loss: 0.3599
# Epoch 152/1000, Train Loss: 0.1777, Val Loss: 0.3596
# Epoch 153/1000, Train Loss: 0.1778, Val Loss: 0.3594
# Epoch 154/1000, Train Loss: 0.1776, Val Loss: 0.3594
# Epoch 155/1000, Train Loss: 0.1776, Val Loss: 0.3595
# Epoch 156/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 157/1000, Train Loss: 0.1783, Val Loss: 0.3596
# Epoch 158/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 159/1000, Train Loss: 0.1775, Val Loss: 0.3595
# Epoch 160/1000, Train Loss: 0.1783, Val Loss: 0.3597
# Epoch 161/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 162/1000, Train Loss: 0.1780, Val Loss: 0.3599
# Epoch 163/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 164/1000, Train Loss: 0.1776, Val Loss: 0.3596
# Epoch 165/1000, Train Loss: 0.1777, Val Loss: 0.3598
# Epoch 166/1000, Train Loss: 0.1783, Val Loss: 0.3596
# Epoch 167/1000, Train Loss: 0.1781, Val Loss: 0.3601
# Epoch 168/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 169/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 170/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 171/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 172/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 173/1000, Train Loss: 0.1781, Val Loss: 0.3590
# Epoch 174/1000, Train Loss: 0.1777, Val Loss: 0.3599
# Epoch 175/1000, Train Loss: 0.1783, Val Loss: 0.3592
# Epoch 176/1000, Train Loss: 0.1775, Val Loss: 0.3600
# Epoch 177/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 178/1000, Train Loss: 0.1779, Val Loss: 0.3602
# Epoch 179/1000, Train Loss: 0.1774, Val Loss: 0.3595
# Epoch 180/1000, Train Loss: 0.1784, Val Loss: 0.3590
# Epoch 181/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 182/1000, Train Loss: 0.1783, Val Loss: 0.3594
# Epoch 183/1000, Train Loss: 0.1781, Val Loss: 0.3590
# Epoch 184/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 185/1000, Train Loss: 0.1778, Val Loss: 0.3593
# Epoch 186/1000, Train Loss: 0.1777, Val Loss: 0.3598
# Epoch 187/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 188/1000, Train Loss: 0.1784, Val Loss: 0.3593
# Epoch 189/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 190/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 191/1000, Train Loss: 0.1776, Val Loss: 0.3596
# Epoch 192/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 193/1000, Train Loss: 0.1784, Val Loss: 0.3590
# Epoch 194/1000, Train Loss: 0.1773, Val Loss: 0.3602
# Epoch 195/1000, Train Loss: 0.1783, Val Loss: 0.3598
# Epoch 196/1000, Train Loss: 0.1785, Val Loss: 0.3592
# Epoch 197/1000, Train Loss: 0.1778, Val Loss: 0.3599
# Epoch 198/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 199/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 200/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 201/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 202/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 203/1000, Train Loss: 0.1780, Val Loss: 0.3598
# Epoch 204/1000, Train Loss: 0.1775, Val Loss: 0.3593
# Epoch 205/1000, Train Loss: 0.1783, Val Loss: 0.3590
# Epoch 206/1000, Train Loss: 0.1783, Val Loss: 0.3593
# Epoch 207/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 208/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 209/1000, Train Loss: 0.1780, Val Loss: 0.3600
# Epoch 210/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 211/1000, Train Loss: 0.1782, Val Loss: 0.3592
# Epoch 212/1000, Train Loss: 0.1777, Val Loss: 0.3598
# Epoch 213/1000, Train Loss: 0.1779, Val Loss: 0.3592
# Epoch 214/1000, Train Loss: 0.1775, Val Loss: 0.3594
# Epoch 215/1000, Train Loss: 0.1774, Val Loss: 0.3595
# Epoch 216/1000, Train Loss: 0.1785, Val Loss: 0.3594
# Epoch 217/1000, Train Loss: 0.1783, Val Loss: 0.3594
# Epoch 218/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 219/1000, Train Loss: 0.1778, Val Loss: 0.3602
# Epoch 220/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 221/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 222/1000, Train Loss: 0.1783, Val Loss: 0.3597
# Epoch 223/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 224/1000, Train Loss: 0.1783, Val Loss: 0.3598
# Epoch 225/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 226/1000, Train Loss: 0.1782, Val Loss: 0.3605
# Epoch 227/1000, Train Loss: 0.1778, Val Loss: 0.3600
# Epoch 228/1000, Train Loss: 0.1778, Val Loss: 0.3592
# Epoch 229/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 230/1000, Train Loss: 0.1780, Val Loss: 0.3592
# Epoch 231/1000, Train Loss: 0.1786, Val Loss: 0.3602
# Epoch 232/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 233/1000, Train Loss: 0.1782, Val Loss: 0.3592
# Epoch 234/1000, Train Loss: 0.1784, Val Loss: 0.3594
# Epoch 235/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 236/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 237/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 238/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 239/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 240/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 241/1000, Train Loss: 0.1782, Val Loss: 0.3596
# Epoch 242/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 243/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 244/1000, Train Loss: 0.1784, Val Loss: 0.3596
# Epoch 245/1000, Train Loss: 0.1784, Val Loss: 0.3599
# Epoch 246/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 247/1000, Train Loss: 0.1778, Val Loss: 0.3594
# Epoch 248/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 249/1000, Train Loss: 0.1777, Val Loss: 0.3602
# Epoch 250/1000, Train Loss: 0.1776, Val Loss: 0.3595
# Epoch 251/1000, Train Loss: 0.1781, Val Loss: 0.3594
# Epoch 252/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 253/1000, Train Loss: 0.1784, Val Loss: 0.3598
# Epoch 254/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 255/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 256/1000, Train Loss: 0.1781, Val Loss: 0.3602
# Epoch 257/1000, Train Loss: 0.1779, Val Loss: 0.3593
# Epoch 258/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 259/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 260/1000, Train Loss: 0.1783, Val Loss: 0.3599
# Epoch 261/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 262/1000, Train Loss: 0.1777, Val Loss: 0.3590
# Epoch 263/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 264/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 265/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 266/1000, Train Loss: 0.1781, Val Loss: 0.3594
# Epoch 267/1000, Train Loss: 0.1780, Val Loss: 0.3600
# Epoch 268/1000, Train Loss: 0.1783, Val Loss: 0.3597
# Epoch 269/1000, Train Loss: 0.1783, Val Loss: 0.3593
# Epoch 270/1000, Train Loss: 0.1782, Val Loss: 0.3599
# Epoch 271/1000, Train Loss: 0.1780, Val Loss: 0.3601
# Epoch 272/1000, Train Loss: 0.1780, Val Loss: 0.3599
# Epoch 273/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 274/1000, Train Loss: 0.1776, Val Loss: 0.3594
# Epoch 275/1000, Train Loss: 0.1777, Val Loss: 0.3595
# Epoch 276/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 277/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 278/1000, Train Loss: 0.1775, Val Loss: 0.3597
# Epoch 279/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 280/1000, Train Loss: 0.1779, Val Loss: 0.3593
# Epoch 281/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 282/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 283/1000, Train Loss: 0.1778, Val Loss: 0.3599
# Epoch 284/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 285/1000, Train Loss: 0.1781, Val Loss: 0.3595
# Epoch 286/1000, Train Loss: 0.1773, Val Loss: 0.3602
# Epoch 287/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 288/1000, Train Loss: 0.1783, Val Loss: 0.3600
# Epoch 289/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 290/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 291/1000, Train Loss: 0.1781, Val Loss: 0.3602
# Epoch 292/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 293/1000, Train Loss: 0.1782, Val Loss: 0.3592
# Epoch 294/1000, Train Loss: 0.1785, Val Loss: 0.3594
# Epoch 295/1000, Train Loss: 0.1782, Val Loss: 0.3592
# Epoch 296/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 297/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 298/1000, Train Loss: 0.1779, Val Loss: 0.3592
# Epoch 299/1000, Train Loss: 0.1778, Val Loss: 0.3596
# Epoch 300/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 301/1000, Train Loss: 0.1781, Val Loss: 0.3595
# Epoch 302/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 303/1000, Train Loss: 0.1777, Val Loss: 0.3596
# Epoch 304/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 305/1000, Train Loss: 0.1777, Val Loss: 0.3592
# Epoch 306/1000, Train Loss: 0.1784, Val Loss: 0.3597
# Epoch 307/1000, Train Loss: 0.1775, Val Loss: 0.3594
# Epoch 308/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 309/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 310/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 311/1000, Train Loss: 0.1784, Val Loss: 0.3593
# Epoch 312/1000, Train Loss: 0.1777, Val Loss: 0.3596
# Epoch 313/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 314/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 315/1000, Train Loss: 0.1778, Val Loss: 0.3602
# Epoch 316/1000, Train Loss: 0.1775, Val Loss: 0.3594
# Epoch 317/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 318/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 319/1000, Train Loss: 0.1777, Val Loss: 0.3598
# Epoch 320/1000, Train Loss: 0.1779, Val Loss: 0.3592
# Epoch 321/1000, Train Loss: 0.1781, Val Loss: 0.3594
# Epoch 322/1000, Train Loss: 0.1778, Val Loss: 0.3599
# Epoch 323/1000, Train Loss: 0.1780, Val Loss: 0.3592
# Epoch 324/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 325/1000, Train Loss: 0.1779, Val Loss: 0.3600
# Epoch 326/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 327/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 328/1000, Train Loss: 0.1778, Val Loss: 0.3599
# Epoch 329/1000, Train Loss: 0.1777, Val Loss: 0.3601
# Epoch 330/1000, Train Loss: 0.1781, Val Loss: 0.3594
# Epoch 331/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 332/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 333/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 334/1000, Train Loss: 0.1778, Val Loss: 0.3601
# Epoch 335/1000, Train Loss: 0.1775, Val Loss: 0.3595
# Epoch 336/1000, Train Loss: 0.1778, Val Loss: 0.3596
# Epoch 337/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 338/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 339/1000, Train Loss: 0.1776, Val Loss: 0.3597
# Epoch 340/1000, Train Loss: 0.1776, Val Loss: 0.3599
# Epoch 341/1000, Train Loss: 0.1778, Val Loss: 0.3600
# Epoch 342/1000, Train Loss: 0.1781, Val Loss: 0.3592
# Epoch 343/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 344/1000, Train Loss: 0.1782, Val Loss: 0.3596
# Epoch 345/1000, Train Loss: 0.1777, Val Loss: 0.3597
# Epoch 346/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 347/1000, Train Loss: 0.1776, Val Loss: 0.3601
# Epoch 348/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 349/1000, Train Loss: 0.1782, Val Loss: 0.3601
# Epoch 350/1000, Train Loss: 0.1782, Val Loss: 0.3596
# Epoch 351/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 352/1000, Train Loss: 0.1784, Val Loss: 0.3593
# Epoch 353/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 354/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 355/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 356/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 357/1000, Train Loss: 0.1777, Val Loss: 0.3595
# Epoch 358/1000, Train Loss: 0.1775, Val Loss: 0.3591
# Epoch 359/1000, Train Loss: 0.1780, Val Loss: 0.3600
# Epoch 360/1000, Train Loss: 0.1786, Val Loss: 0.3591
# Epoch 361/1000, Train Loss: 0.1784, Val Loss: 0.3593
# Epoch 362/1000, Train Loss: 0.1775, Val Loss: 0.3593
# Epoch 363/1000, Train Loss: 0.1786, Val Loss: 0.3597
# Epoch 364/1000, Train Loss: 0.1783, Val Loss: 0.3597
# Epoch 365/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 366/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 367/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 368/1000, Train Loss: 0.1781, Val Loss: 0.3601
# Epoch 369/1000, Train Loss: 0.1775, Val Loss: 0.3596
# Epoch 370/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 371/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 372/1000, Train Loss: 0.1778, Val Loss: 0.3600
# Epoch 373/1000, Train Loss: 0.1784, Val Loss: 0.3592
# Epoch 374/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 375/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 376/1000, Train Loss: 0.1781, Val Loss: 0.3594
# Epoch 377/1000, Train Loss: 0.1783, Val Loss: 0.3595
# Epoch 378/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 379/1000, Train Loss: 0.1777, Val Loss: 0.3598
# Epoch 380/1000, Train Loss: 0.1779, Val Loss: 0.3594
# Epoch 381/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 382/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 383/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 384/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 385/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 386/1000, Train Loss: 0.1786, Val Loss: 0.3594
# Epoch 387/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 388/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 389/1000, Train Loss: 0.1783, Val Loss: 0.3600
# Epoch 390/1000, Train Loss: 0.1776, Val Loss: 0.3595
# Epoch 391/1000, Train Loss: 0.1779, Val Loss: 0.3589
# Epoch 392/1000, Train Loss: 0.1777, Val Loss: 0.3595
# Epoch 393/1000, Train Loss: 0.1778, Val Loss: 0.3594
# Epoch 394/1000, Train Loss: 0.1772, Val Loss: 0.3594
# Epoch 395/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 396/1000, Train Loss: 0.1786, Val Loss: 0.3597
# Epoch 397/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 398/1000, Train Loss: 0.1783, Val Loss: 0.3593
# Epoch 399/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 400/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 401/1000, Train Loss: 0.1785, Val Loss: 0.3594
# Epoch 402/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 403/1000, Train Loss: 0.1779, Val Loss: 0.3601
# Epoch 404/1000, Train Loss: 0.1779, Val Loss: 0.3600
# Epoch 405/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 406/1000, Train Loss: 0.1785, Val Loss: 0.3597
# Epoch 407/1000, Train Loss: 0.1781, Val Loss: 0.3601
# Epoch 408/1000, Train Loss: 0.1776, Val Loss: 0.3597
# Epoch 409/1000, Train Loss: 0.1784, Val Loss: 0.3598
# Epoch 410/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 411/1000, Train Loss: 0.1784, Val Loss: 0.3596
# Epoch 412/1000, Train Loss: 0.1778, Val Loss: 0.3599
# Epoch 413/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 414/1000, Train Loss: 0.1779, Val Loss: 0.3594
# Epoch 415/1000, Train Loss: 0.1779, Val Loss: 0.3598
# Epoch 416/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 417/1000, Train Loss: 0.1778, Val Loss: 0.3593
# Epoch 418/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 419/1000, Train Loss: 0.1775, Val Loss: 0.3599
# Epoch 420/1000, Train Loss: 0.1782, Val Loss: 0.3599
# Epoch 421/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 422/1000, Train Loss: 0.1778, Val Loss: 0.3598
# Epoch 423/1000, Train Loss: 0.1779, Val Loss: 0.3593
# Epoch 424/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 425/1000, Train Loss: 0.1776, Val Loss: 0.3596
# Epoch 426/1000, Train Loss: 0.1782, Val Loss: 0.3600
# Epoch 427/1000, Train Loss: 0.1779, Val Loss: 0.3600
# Epoch 428/1000, Train Loss: 0.1780, Val Loss: 0.3598
# Epoch 429/1000, Train Loss: 0.1772, Val Loss: 0.3593
# Epoch 430/1000, Train Loss: 0.1782, Val Loss: 0.3600
# Epoch 431/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 432/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 433/1000, Train Loss: 0.1783, Val Loss: 0.3597
# Epoch 434/1000, Train Loss: 0.1786, Val Loss: 0.3594
# Epoch 435/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 436/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 437/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 438/1000, Train Loss: 0.1775, Val Loss: 0.3593
# Epoch 439/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 440/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 441/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 442/1000, Train Loss: 0.1783, Val Loss: 0.3594
# Epoch 443/1000, Train Loss: 0.1782, Val Loss: 0.3600
# Epoch 444/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 445/1000, Train Loss: 0.1775, Val Loss: 0.3597
# Epoch 446/1000, Train Loss: 0.1779, Val Loss: 0.3593
# Epoch 447/1000, Train Loss: 0.1774, Val Loss: 0.3595
# Epoch 448/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 449/1000, Train Loss: 0.1777, Val Loss: 0.3598
# Epoch 450/1000, Train Loss: 0.1778, Val Loss: 0.3602
# Epoch 451/1000, Train Loss: 0.1779, Val Loss: 0.3592
# Epoch 452/1000, Train Loss: 0.1783, Val Loss: 0.3593
# Epoch 453/1000, Train Loss: 0.1781, Val Loss: 0.3593
# Epoch 454/1000, Train Loss: 0.1783, Val Loss: 0.3593
# Epoch 455/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 456/1000, Train Loss: 0.1776, Val Loss: 0.3596
# Epoch 457/1000, Train Loss: 0.1781, Val Loss: 0.3592
# Epoch 458/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 459/1000, Train Loss: 0.1777, Val Loss: 0.3594
# Epoch 460/1000, Train Loss: 0.1780, Val Loss: 0.3602
# Epoch 461/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 462/1000, Train Loss: 0.1773, Val Loss: 0.3589
# Epoch 463/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 464/1000, Train Loss: 0.1781, Val Loss: 0.3590
# Epoch 465/1000, Train Loss: 0.1783, Val Loss: 0.3592
# Epoch 466/1000, Train Loss: 0.1777, Val Loss: 0.3594
# Epoch 467/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 468/1000, Train Loss: 0.1783, Val Loss: 0.3600
# Epoch 469/1000, Train Loss: 0.1780, Val Loss: 0.3600
# Epoch 470/1000, Train Loss: 0.1782, Val Loss: 0.3592
# Epoch 471/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 472/1000, Train Loss: 0.1784, Val Loss: 0.3602
# Epoch 473/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 474/1000, Train Loss: 0.1784, Val Loss: 0.3594
# Epoch 475/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 476/1000, Train Loss: 0.1774, Val Loss: 0.3600
# Epoch 477/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 478/1000, Train Loss: 0.1785, Val Loss: 0.3594
# Epoch 479/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 480/1000, Train Loss: 0.1780, Val Loss: 0.3603
# Epoch 481/1000, Train Loss: 0.1778, Val Loss: 0.3597
# Epoch 482/1000, Train Loss: 0.1778, Val Loss: 0.3602
# Epoch 483/1000, Train Loss: 0.1782, Val Loss: 0.3593
# Epoch 484/1000, Train Loss: 0.1784, Val Loss: 0.3596
# Epoch 485/1000, Train Loss: 0.1776, Val Loss: 0.3600
# Epoch 486/1000, Train Loss: 0.1776, Val Loss: 0.3599
# Epoch 487/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 488/1000, Train Loss: 0.1781, Val Loss: 0.3605
# Epoch 489/1000, Train Loss: 0.1786, Val Loss: 0.3593
# Epoch 490/1000, Train Loss: 0.1782, Val Loss: 0.3601
# Epoch 491/1000, Train Loss: 0.1783, Val Loss: 0.3595
# Epoch 492/1000, Train Loss: 0.1780, Val Loss: 0.3601
# Epoch 493/1000, Train Loss: 0.1780, Val Loss: 0.3599
# Epoch 494/1000, Train Loss: 0.1783, Val Loss: 0.3598
# Epoch 495/1000, Train Loss: 0.1780, Val Loss: 0.3601
# Epoch 496/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 497/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 498/1000, Train Loss: 0.1778, Val Loss: 0.3594
# Epoch 499/1000, Train Loss: 0.1783, Val Loss: 0.3598
# Epoch 500/1000, Train Loss: 0.1778, Val Loss: 0.3598
# Epoch 501/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 502/1000, Train Loss: 0.1779, Val Loss: 0.3592
# Epoch 503/1000, Train Loss: 0.1786, Val Loss: 0.3596
# Epoch 504/1000, Train Loss: 0.1781, Val Loss: 0.3595
# Epoch 505/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 506/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 507/1000, Train Loss: 0.1784, Val Loss: 0.3601
# Epoch 508/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 509/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 510/1000, Train Loss: 0.1782, Val Loss: 0.3594
# Epoch 511/1000, Train Loss: 0.1780, Val Loss: 0.3600
# Epoch 512/1000, Train Loss: 0.1777, Val Loss: 0.3594
# Epoch 513/1000, Train Loss: 0.1783, Val Loss: 0.3595
# Epoch 514/1000, Train Loss: 0.1783, Val Loss: 0.3597
# Epoch 515/1000, Train Loss: 0.1785, Val Loss: 0.3597
# Epoch 516/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 517/1000, Train Loss: 0.1781, Val Loss: 0.3602
# Epoch 518/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 519/1000, Train Loss: 0.1781, Val Loss: 0.3600
# Epoch 520/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 521/1000, Train Loss: 0.1786, Val Loss: 0.3598
# Epoch 522/1000, Train Loss: 0.1782, Val Loss: 0.3596
# Epoch 523/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 524/1000, Train Loss: 0.1784, Val Loss: 0.3594
# Epoch 525/1000, Train Loss: 0.1784, Val Loss: 0.3591
# Epoch 526/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 527/1000, Train Loss: 0.1781, Val Loss: 0.3592
# Epoch 528/1000, Train Loss: 0.1782, Val Loss: 0.3601
# Epoch 529/1000, Train Loss: 0.1775, Val Loss: 0.3605
# Epoch 530/1000, Train Loss: 0.1779, Val Loss: 0.3593
# Epoch 531/1000, Train Loss: 0.1778, Val Loss: 0.3591
# Epoch 532/1000, Train Loss: 0.1782, Val Loss: 0.3600
# Epoch 533/1000, Train Loss: 0.1777, Val Loss: 0.3594
# Epoch 534/1000, Train Loss: 0.1778, Val Loss: 0.3596
# Epoch 535/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 536/1000, Train Loss: 0.1782, Val Loss: 0.3595
# Epoch 537/1000, Train Loss: 0.1780, Val Loss: 0.3593
# Epoch 538/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 539/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 540/1000, Train Loss: 0.1785, Val Loss: 0.3597
# Epoch 541/1000, Train Loss: 0.1779, Val Loss: 0.3594
# Epoch 542/1000, Train Loss: 0.1783, Val Loss: 0.3591
# Epoch 543/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 544/1000, Train Loss: 0.1783, Val Loss: 0.3595
# Epoch 545/1000, Train Loss: 0.1777, Val Loss: 0.3597
# Epoch 546/1000, Train Loss: 0.1776, Val Loss: 0.3594
# Epoch 547/1000, Train Loss: 0.1776, Val Loss: 0.3597
# Epoch 548/1000, Train Loss: 0.1776, Val Loss: 0.3595
# Epoch 549/1000, Train Loss: 0.1782, Val Loss: 0.3599
# Epoch 550/1000, Train Loss: 0.1778, Val Loss: 0.3596
# Epoch 551/1000, Train Loss: 0.1785, Val Loss: 0.3595
# Epoch 552/1000, Train Loss: 0.1783, Val Loss: 0.3594
# Epoch 553/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 554/1000, Train Loss: 0.1779, Val Loss: 0.3596
# Epoch 555/1000, Train Loss: 0.1781, Val Loss: 0.3597
# Epoch 556/1000, Train Loss: 0.1784, Val Loss: 0.3595
# Epoch 557/1000, Train Loss: 0.1779, Val Loss: 0.3594
# Epoch 558/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 559/1000, Train Loss: 0.1778, Val Loss: 0.3597
# Epoch 560/1000, Train Loss: 0.1780, Val Loss: 0.3601
# Epoch 561/1000, Train Loss: 0.1783, Val Loss: 0.3588
# Epoch 562/1000, Train Loss: 0.1781, Val Loss: 0.3595
# Epoch 563/1000, Train Loss: 0.1779, Val Loss: 0.3601
# Epoch 564/1000, Train Loss: 0.1781, Val Loss: 0.3602
# Epoch 565/1000, Train Loss: 0.1778, Val Loss: 0.3598
# Epoch 566/1000, Train Loss: 0.1784, Val Loss: 0.3598
# Epoch 567/1000, Train Loss: 0.1779, Val Loss: 0.3595
# Epoch 568/1000, Train Loss: 0.1779, Val Loss: 0.3602
# Epoch 569/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 570/1000, Train Loss: 0.1781, Val Loss: 0.3599
# Epoch 571/1000, Train Loss: 0.1782, Val Loss: 0.3593
# Epoch 572/1000, Train Loss: 0.1776, Val Loss: 0.3597
# Epoch 573/1000, Train Loss: 0.1780, Val Loss: 0.3598
# Epoch 574/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 575/1000, Train Loss: 0.1780, Val Loss: 0.3597
# Epoch 576/1000, Train Loss: 0.1778, Val Loss: 0.3595
# Epoch 577/1000, Train Loss: 0.1779, Val Loss: 0.3597
# Epoch 578/1000, Train Loss: 0.1778, Val Loss: 0.3600
# Epoch 579/1000, Train Loss: 0.1781, Val Loss: 0.3603
# Epoch 580/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 581/1000, Train Loss: 0.1776, Val Loss: 0.3593
# Epoch 582/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 583/1000, Train Loss: 0.1783, Val Loss: 0.3593
# Epoch 584/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 585/1000, Train Loss: 0.1780, Val Loss: 0.3592
# Epoch 586/1000, Train Loss: 0.1780, Val Loss: 0.3594
# Epoch 587/1000, Train Loss: 0.1778, Val Loss: 0.3592
# Epoch 588/1000, Train Loss: 0.1779, Val Loss: 0.3591
# Epoch 589/1000, Train Loss: 0.1774, Val Loss: 0.3593
# Epoch 590/1000, Train Loss: 0.1781, Val Loss: 0.3595
# Epoch 591/1000, Train Loss: 0.1782, Val Loss: 0.3598
# Epoch 592/1000, Train Loss: 0.1778, Val Loss: 0.3596
# Epoch 593/1000, Train Loss: 0.1781, Val Loss: 0.3598
# Epoch 594/1000, Train Loss: 0.1782, Val Loss: 0.3596
# Epoch 595/1000, Train Loss: 0.1780, Val Loss: 0.3596
# Epoch 596/1000, Train Loss: 0.1781, Val Loss: 0.3592
# Epoch 597/1000, Train Loss: 0.1780, Val Loss: 0.3595
# Epoch 598/1000, Train Loss: 0.1774, Val Loss: 0.3596
# Epoch 599/1000, Train Loss: 0.1783, Val Loss: 0.3594
# Epoch 600/1000, Train Loss: 0.1782, Val Loss: 0.3593
# Epoch 601/1000, Train Loss: 0.1782, Val Loss: 0.3597
# Epoch 602/1000, Train Loss: 0.1786, Val Loss: 0.3602
# Epoch 603/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 604/1000, Train Loss: 0.1782, Val Loss: 0.3599
# Epoch 605/1000, Train Loss: 0.1779, Val Loss: 0.3599
# Epoch 606/1000, Train Loss: 0.1781, Val Loss: 0.3596
# Epoch 607/1000, Train Loss: 0.1783, Val Loss: 0.3597
# Epoch 608/1000, Train Loss: 0.1787, Val Loss: 0.3598
# Epoch 609/1000, Train Loss: 0.1779, Val Loss: 0.3594
